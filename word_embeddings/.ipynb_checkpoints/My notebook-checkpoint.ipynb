# %%
from collections import Counter

# %%
from collections import Counter

# Assuming you have your words in a list
words = ["hello", "world", "hello", "test", "python", "world", "hello"]

# Count word frequencies
word_counts = Counter(words)

# Filter out words that appear exactly once
filtered_words = [word for word in words if word_counts[word] > 1]

print(f"Original: {len(words)} total words, {len(set(words))} unique words")
print(f"Filtered: {len(filtered_words)} total words, {len(set(filtered_words))} unique words")
print(f"\nWord frequencies after filtering:")
print(Counter(filtered_words))
# Out:
# Original: 7 total words, 4 unique words
# Filtered: 5 total words, 2 unique words
#
# Word frequencies after filtering:
# Counter({'hello': 3, 'world': 2})

# %%
file_p = "../text.txt"

with open(file_p, "r") as f:
    txt = f.read()
words = txt.split()

# %%
word_counts = Counter(words)
filtered_words = [word for word in words if word_counts[word]>5]
len(filtered_words), len(set(filtered_words))
# Out:
# (324559, 5196)

# %%
vocab = list(set(filtered_words))
vocab.sort()
vocab_len= len(vocab)
total_words = len(filtered_words)

# %%
encoding = {word: i for i, word in enumerate(vocab)} # Remove un commone words 
encoding["pari"]
# Out:
# 3876

# %%
decoding = {i: word for i, word in enumerate(vocab)}
decoding[3876]
# Out:
# 'pari'

# %%
wordIds_to_tokens = lambda x:[encoding[filtered_words[i]] for i in x]
wordIds_to_tokens([10,11, 12])
# Out:
# [3809, 4355, 4671]

# %%
import numpy as np
context_sz = 2  # 2 words to left, 2 words to right. 

def getData(bs=8):
    trgt = [np.random.randint(0, total_words) for i in range(1)]
    context = [[i-2, i-1, i+1, i+2] for i in trgt]

    trgt_tokens = wordIds_to_tokens(trgt)
    context_tokens = wordIds_to_tokens(context[0])
    return (trgt_tokens, context_tokens)

getData()
# Out:
# ([2301], [3565, 4959, 942, 440])

# %%
import torch
import torch.nn as nn

class Embeddings(nn.Module):
    def __init__(self, vocab_sz, v_dim):
        super(Embeddings, self).__init__()
        self.embeddings = nn.Embedding(vocab_sz, v_dim)
        self.l1 = nn.Linear(v_dim, 128)
        self.a1 = nn.ReLU()
        self.l2 = nn.Linear(128, vocab_sz)
        self.a2 = nn.LogSoftmax(dim =-1)

        
    def forward(self, embeds):
        out = self.l1(embeds)
        out = self.a1(out)
        out = self.l2(out)
        out = self.a2(out)
        return out

    def get_word_embeddings(self, token):
        if not isinstance(token, torch.Tensor):
            token = torch.tensor(token, dtype=torch.long)
        return self.embeddings(token)
        

    def context_mean(self, ints):
        embeds = torch.stack([self.get_word_embeddings(i) for i in ints])
        return embeds.mean(dim=0) # DIV by 4 as context_sz is 2 to get the mean

# %%
model = Embeddings(vocab_len, 100)
loss_fn = nn.NLLLoss()
optim = torch.optim.SGD(model.parameters(), lr=0.001)

# %%
for i in range(200):
    total_loss = 0
    for _ in range(8):
        trgt, context_vect = getData()
        embeds = model.context_mean(context_vect)
        log_preds = model(embeds)
        trgt_tensor = torch.tensor([trgt], dtype=torch.long)
        loss = loss_fn(log_preds.unsqueeze(0), trgt_tensor[0])
        total_loss += loss
        
    optim.zero_grad()
    total_loss.backward()
    optim.step()
    print(f"Step: {i}, Loss: {total_loss}")


# loss = loss_fn(log_preds, trgt_vect)
# loss
# Out:
# /tmp/ipykernel_5350/1573251458.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(