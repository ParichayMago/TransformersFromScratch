# %%
import torch
import torch.nn as nn
import tiktoken

# %%
def get_data:

# %%
class Encoder_Congig:
    def __init__(
        layers =6, 
        v_size = 50257,
        dim = 512,
        heads = 12,
    )

# %%
class Tokenizing:
    def __init__(self):
        self.enc = tiktoken.get_encoding("gpt2")

    def encode(self, txt):
        return self.enc.encode(txt)

    def decode(self, ints):
        return self.enc.decode(ints)

# %%
class EncoderEmbedding:
    def __init__(self, config):
        self.word_embeddings = nn.Embeddings(config.vocab, config.dim)
        self.position_embeddings = torch.arange(0, vocab)

    def add_position_embeddings(self):

# %%
tokenizer = Tokenizing()
ints = tokenizer.encode("hello worlds no this is bs")

# %%
ints
# Out:
# [31373, 11621, 645, 428, 318, 275, 82]
