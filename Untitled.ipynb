# %%
import torch
import torch.nn as nn
import tiktoken

# %%
class BERTConfig:
   def __init__(
        self, 
        vocab_size=30522,
        hidden_size = 768,
        heads = 12
    ):
       self.vocab_size = vocab_size
       self.hidden_size = hidden_size
       self.heads = heads

# %%
# Used to break words into smaller units (tokens) and then -> integers
class BPETokenizer:
    def __init__(self):
        self.enc = tiktoken.get_encoding("r50k_base")

    def encode(self, text):
        return self.enc.encode(text)

    def decode(self, ints):
        return self.enc.decode(ints)

# %%
tokenizer = BPETokenizer()
tokenizer.encode("hello world")
# Out:
# [31373, 995]

# %%
class BERTEmbeddings(nn.Module):
    def __init__(self, n_dim, ):
        self.n_voc = 50000
        self.n_dim =  728
        self.word_embeddings = nn.Embedding(n_voc, n_dim)
        self.segment_embeddings = nn.Embeddings
        self.position = nn.Embeddings
        
    def forward(self):
        n_voc

# %%
emb.weight
# Out:
# Parameter containing:
# tensor([[ 0.0259,  0.7050,  0.2382, -0.4228, -0.8679, -0.0909,  0.0094, -0.4955,
#           1.4740,  0.0906]], requires_grad=True)
